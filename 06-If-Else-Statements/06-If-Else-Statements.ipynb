# %% [markdown]
# # 06-If-Else-Statements
#
#
# Conditional statements, often referred to as if-then statements, let you control what pieces of code are run based on the value of some Boolean condition. Here's an example:
#
# ```python
#
#     if age >= 16:
#        print("You can drive in US!")
#     elif age >= 18:
#         print("You can drive!")
#     else:
#         print("Be health, ride a bike!")
# ```
#
# Basically you can use if statements to controll the flow of execution.
#
# ### Logic Operators
#
# In this module you will recap the logic operators to use in if statements.
#
# - Equals: a == b
# - Not Equals: a != b
# - Less than: a < b
# - Less than or equal to: a <= b
# - Greater than: a > b
# - Greater than or equal to: a >= b
#
# ### Indentation
#
# Identation is very important in Python. With identation, is possible to delimit the scope of execution of your code, so in every python code, the identation is checked:
#
# ```python
# if age > 18:
# print("You got an error!") # this code is not idented
#
# #Right way
#
# if age > 18:
#     print("OK")            # this code is idented
#
# ```
#
#
# ### Short hand If and If-Else (Ternary Operators)
#
# You can write your if statements "inline".
#
# This form is called "Ternary Operators", and can be used in simple expressions:
#
# ```python
# a = 2
# b = 330
#
# # If
# if a > b: print("a is greater than b")
#
# # If-Else
# print("A") if a > b else print("B")
# ```
#
# ### Nested If
#
# Its possible to write nested Ifs.
#
# ```python
# coins = 1000
# name = "Mario"
#
# if coins >= 1000:
#     if name == "Mario":
#         print("You can enter in the castle sir!")
#     else:
#         print("Please, wait here!")
# else:
#     print("Stay away or I will call the police!")
#
# ```
#
# ### in - not in
#
# The operator "in" and "not" can be used to check items inside a list:
#
# ```python
#
# pizza_ingredients = ["pineapple","chocolate","salt","cherry"]
#
# if "pineapple" in pizza_ingredients:
#     print("Yuummmyy :P")
#
# if "pepperoni" not in pizza_ingredients:
#     print("can I call this \"pizza\"?")
#
# ```
#
#
# ### and
#
# To create more complex and easy to read boolean sentences, use the operator "and":
#
# ```python
# pizza_ingredients = ["pineapple","chocolate","salt","cherry"]
#
# if "pineapple" in pizza_ingredients and "pepperoni" not in pizza_ingredients :
#     print("really?")
#
# ```
#
# ### or
#
# You can use the operator "or" too:
#
# ```python
# pizza_ingredients = ["pineapple","chocolate","salt","cherry"]
#
# if "pineapple" in pizza_ingredients or "pepperoni" in pizza_ingredients :
#     print("Yuummmy")
#
# ```
#
#
# ### Challenges
#
# Its time to check what you learn. Please fix or complete the code bellow, after that execute the next cell with the tests. Good Lucky!

# %%
client = {
    "name": "Toad",
    "age": 16,
    "coins": 100
}

store = {
    "mushrooms": 10,
    "stars": 5,
    "coins": 1000,
    "minimal_age_mushrooms": 15,
    "minimal_age_stars": 18
}


"""
CHALLENGE 1 

Toad wants to buy a mushroom, check if he has sufficient coins and if his age is greater or equal
to the minimum age to buy mushrooms.
Every mushroom costs 20, so debit this amount from their account and add it to the store account.
"""
toad_can_buy_mushroom = None

# complete this condition and fix the errors, remember the identation
if client["coins"] >= 20 *** client["age"] >= store["minimal_age_mushrooms"]:
toad_can_buy_mushroom = True
# complete the code to debit from client and deposit to store
client["coins"] = client["coins"] - 20
store["coins"] = *** + 20
store["mushrooms"] = store["mushrooms"] ***
 print("Thanks!")
else:
    toad_can_buy_mushroom = False
    print("Stoped transaction!")

"""
CHALLENGE 2

Now Toad wants to buy a star, check if he has sufficient coins 
and if his age is greater than minimal age to buy stars.
Every star costs 80

"""

toad_can_buy_star = None

# complete this condition and fix the errors, remember the identation
if client["coins"] >= 80 and client["age"] >= store["minimal_age_stars"]:
    toad_can_buy_star = ***
    # complete the code to debit from client and deposit to store
        client["coins"] = client["coins"] - 80
        store["coins"] = store["coins"] + 80
    print("Thanks!")
else:
    toad_can_buy_star = False
    print("Stoped transaction!")

# %%
# Execute this tests when you finish all the challenges
import test_script

test_script.check_toad_can_buy_mushroom(toad_can_buy_mushroom, client, store)   
test_script.check_toad_can_buy_star(toad_can_buy_star, client, store)
